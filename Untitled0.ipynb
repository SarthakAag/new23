# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

stock = "POWERGRID.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2025, 11, 1)

df = yf.download(stock, start, end)
# Out:
# C:\Users\sarth\AppData\Local\Temp\ipykernel_24636\903247088.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# Date
# 2007-10-05    31.768667    34.579216    26.258098    28.358115    855215656
# 2007-10-08    30.142338    32.842358    29.952862    32.842358    126671715
# 2007-10-09    32.194992    32.479204    28.531805    30.158133    116725709
# 2007-10-10    32.494984    33.158147    32.210772    33.031829     67931378
# 2007-10-11    36.126598    37.895034    32.210780    37.895034    106320954

# %%
df.shape
# Out:
# (4439, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4439 entries, 2007-10-05 to 2025-10-03
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, POWERGRID.NS)   4439 non-null   float64
#  1   (High, POWERGRID.NS)    4439 non-null   float64
#  2   (Low, POWERGRID.NS)     4439 non-null   float64
#  3   (Open, POWERGRID.NS)    4439 non-null   float64
#  4   (Volume, POWERGRID.NS)  4439 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 208.1 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   POWERGRID.NS    0
# High    POWERGRID.NS    0
# Low     POWERGRID.NS    0
# Open    POWERGRID.NS    0
# Volume  POWERGRID.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS  POWERGRID.NS
# count   4439.000000  4439.000000  4439.000000  4439.000000  4.439000e+03
# mean      89.404533    90.542808    88.286853    89.447655  1.192181e+07
# std       78.171181    79.061284    77.265150    78.175487  2.012684e+07
# min       18.548222    19.827409    16.629440    19.731469  0.000000e+00
# 25%       36.015781    36.590353    35.549274    36.063116  4.933244e+06
# 50%       65.639626    66.487312    64.718235    65.463972  8.544753e+06
# 75%       98.745544   100.116955    96.987599    98.686396  1.378587e+07
# max      354.580750   355.356950   346.576122   353.222365  8.552157e+08

# %%
df = df.reset_index()
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'POWERGRID.NS'),
#             (  'High', 'POWERGRID.NS'),
#             (   'Low', 'POWERGRID.NS'),
#             (  'Open', 'POWERGRID.NS'),
#             ('Volume', 'POWERGRID.NS')],
#            names=['Price', 'Ticker'])

# %%
df.to_csv("powergrid.csv")
data01 = pd.read_csv("powergrid.csv")
data01.head()
# Out:
#     Price        Date               Close               High  \
# 0  Ticker         NaN        POWERGRID.NS       POWERGRID.NS
# 1       0  2007-10-05  31.768667221069336  34.57921595595695
# 2       1  2007-10-08  30.142337799072266  32.84235832798398
# 3       2  2007-10-09   32.19499206542969  32.47920391633825
# 4       3  2007-10-10    32.4949836730957  33.15814730449772
#
#                   Low                Open        Volume
# 0        POWERGRID.NS        POWERGRID.NS  POWERGRID.NS
# 1  26.258097754841593  28.358114831039718     855215656
# 2  29.952861847653757   32.84235832798398     126671715
# 3   28.53180520038112   30.15813261471511     116725709
# 4   32.21077191198066   33.03182930053533      67931378

# %%
# Candlesticks
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = data01['Date'], open = data01['Open'],
                                    high = data01['High'],
                                    low = data01['Low'],
                                    close = data01['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker            POWERGRID.NS POWERGRID.NS POWERGRID.NS POWERGRID.NS
# 0      2007-10-05    31.768667    34.579216    26.258098    28.358115
# 1      2007-10-08    30.142338    32.842358    29.952862    32.842358
# 2      2007-10-09    32.194992    32.479204    28.531805    30.158133
# 3      2007-10-10    32.494984    33.158147    32.210772    33.031829
# 4      2007-10-11    36.126598    37.895034    32.210780    37.895034
#
# Price        Volume
# Ticker POWERGRID.NS
# 0         855215656
# 1         126671715
# 2         116725709
# 3          67931378
# 4         106320954

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High prices over time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume', linewidth = 2)
plt.title(f'{stock} Volume over time')
plt.legend()
plt.show()

# %%
# Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# moving average for last 5 days -> null null null null 30.0 40.0 50.0

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# Ticker  POWERGRID.NS
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 4434      289.988156
# 4435      289.713461
# 4436      289.548309
# 4437      289.408050
# 4438      289.321451
#
# [4439 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Average 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
ema100 = df.Close.ewm(span=100, adjust = False).mean()
ema200 = df['Close'].ewm(span=200, adjust = False).mean()
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp. Moving Average 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp. Moving Average 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
# Training & Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])
data_training.shape
(2945, 1)
data_testing.shape
(1263, 1)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.19808604],
#        [0.17371824],
#        [0.2044738 ],
#        ...,
#        [0.7176771 ],
#        [0.69856719],
#        [0.70796559]], shape=(3107, 1))

# %%
data_training_array.shape[0]
# Out:
# 3107

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train  = np.array(x_train), np.array(y_train)
x_train.shape
# Out:
# (3007, 100, 1)

# %%
# Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units = 1))
model.summary()
# Out:
# C:\Users\sarth\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100, 80)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 120)            │        96,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 120)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           121 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 178,761 (698.29 KB)
#  Trainable params: 178,761 (698.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 21s 172ms/step - loss: 0.0375
# Epoch 2/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 174ms/step - loss: 0.0092
# Epoch 3/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - loss: 0.0072
# Epoch 4/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 24s 213ms/step - loss: 0.0067
# Epoch 5/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - loss: 0.0065
# Epoch 6/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 20s 213ms/step - loss: 0.0058
# Epoch 7/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - loss: 0.0058
# Epoch 8/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - loss: 0.0053
# Epoch 9/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step - loss: 0.0053
# Epoch 10/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 0.0049
# Epoch 11/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 23s 200ms/step - loss: 0.0043
# Epoch 12/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 176ms/step - loss: 0.0044
# Epoch 13/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 183ms/step - loss: 0.0042
# Epoch 14/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 192ms/step - loss: 0.0039
# Epoch 15/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - loss: 0.0041
# Epoch 16/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 189ms/step - loss: 0.0039
# Epoch 17/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 20s 212ms/step - loss: 0.0040
# Epoch 18/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 195ms/step - loss: 0.0034
# Epoch 19/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 172ms/step - loss: 0.0034
# Epoch 20/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 21s 175ms/step - loss: 0.0032
# Epoch 21/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 0.0030
# Epoch 22/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 181ms/step - loss: 0.0031
# Epoch 23/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - loss: 0.0030
# Epoch 24/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - loss: 0.0029
# Epoch 25/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - loss: 0.0027
# Epoch 26/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - loss: 0.0028
# Epoch 27/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - loss: 0.0027
# Epoch 28/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - loss: 0.0027
# Epoch 29/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - loss: 0.0024
# Epoch 30/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - loss: 0.0027
# Epoch 31/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 21s 174ms/step - loss: 0.0026
# Epoch 32/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 23s 199ms/step - loss: 0.0024
# Epoch 33/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - loss: 0.0027
# Epoch 34/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 180ms/step - loss: 0.0025
# Epoch 35/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - loss: 0.0024
# Epoch 36/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.0023
# Epoch 37/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 191ms/step - loss: 0.0024
# Epoch 38/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 19s 196ms/step - loss: 0.0027
# Epoch 39/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 18s 186ms/step - loss: 0.0025
# Epoch 40/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 21s 192ms/step - loss: 0.0023
# Epoch 41/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - loss: 0.0023
# Epoch 42/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - loss: 0.0023
# Epoch 43/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - loss: 0.0024
# Epoch 44/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 175ms/step - loss: 0.0024
# Epoch 45/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - loss: 0.0025
# Epoch 46/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 173ms/step - loss: 0.0025
# Epoch 47/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 16s 175ms/step - loss: 0.0024
# Epoch 48/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - loss: 0.0023
# Epoch 49/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 17s 178ms/step - loss: 0.0025
# Epoch 50/50
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 20s 210ms/step - loss: 0.0023

# %%
past_100_days = data_training.tail(100)
final_df = pd.concat([past_100_days, data_testing], ignore_index = True)

# %%
final_df.head()
# Out:
# Ticker  POWERGRID.NS
# 0          76.248154
# 1          76.752327
# 2          76.732140
# 3          78.849579
# 4          78.688263

# %%
input_data = scaler.fit_transform(final_df)
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test  = np.array(x_test), np.array(y_test)
x_test.shape
# Out:
# (1332, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step

# %%
y_predicted.shape
# Out:
# (1332, 1)

# %%
scaler.scale_
# Out:
# array([0.00339787])

# %%
scaler_factor = 1 / 0.0035166
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
